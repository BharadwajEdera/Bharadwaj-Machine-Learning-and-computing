# %%
import cv2
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Bharadwaj\\IIST\\COMPUTER VISION'

# %% [markdown]
# # Program: Loading,   Exploring, and Showing an Image

# %%
import cv2
# image path
image_path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
# Read or load image from its path
image = cv2.imread(image_path)
# image is a NumPy array

print("Dimensions of the image: ",image.ndim)
print("Image height: ", format(image.shape[0]))
#print("Image width: ", format(image.shape[1]))
#print("Image channels: ", format(image.shape[2]))
#print("Size of the image array: ", image.size) 
# Display the image and wait until a key is pressed 
plt.imshow(image)
# Out:
# Dimensions of the image:  3
# Image height:  225

# %%
cv2.imshow("My Image", image)
cv2.waitKey(0)

# %%
image.shape
# Out:
# (225, 360, 3)

# %% [markdown]
# # Program: OpenCV Code to Access and Manipulate Pixels

# %%
from __future__ import print_function
import cv2

# image path 

image_path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg" 

# Read or load image from its path 

image = cv2.imread(image_path) 

# Access pixel at (0,0) location

(b, g, r) = image[0,0] 

print("Blue, Green and Red values at (0,0): ", format((b, g, r)))

# Manipulate pixels and show modified image 

image[150:180,150:180] = (255, 255, 0)
plt.imshow(image)
# Out:
# Blue, Green and Red values at (0,0):  (29, 37, 44)

# %%
cv2.imshow("Modified Image", image) 

cv2.waitKey(0)

# %%
image.shape
# Out:
# (225, 360, 3)

# %%
(b, g, r) = image[0,0] 
print((b, g, r) )
# Out:
# (29, 37, 44)

# %% [markdown]
# # Drawing a Line on an Image

# %%
from __future__ import print_function
import cv2

# image path
image_path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg" 
# Read or load image from its path
image = cv2.imread(image_path)

# set start and end coordinates
start = (0, 0)
end = (image.shape[1], image.shape[0])
# set the color in BGR
color = (255,0,0)
# set thickness in pixel
thickness = 4
cv2.line(image, start, end, color, thickness)

plt.imshow(image)

# %%
#display the modified image
cv2.imshow("Modified Image", image)
cv2.waitKey(0)

# %%
from __future__ import print_function
import cv2

# image path
image_path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg" 
# Read or load image from its path
image = cv2.imread(image_path)

# set start and end coordinates
start1 = (0, 0)
end1 = (image.shape[1], image.shape[0])
# set the color in BGR
color1 = (255,0,0)
# set thickness in pixel
thickness = 4

cv2.line(image, start1, end1, color1, thickness)

start2 = (0, 255)

end2 = ( 360 , 0 )

color2 = (0,0,255)

cv2.line(image, start2, end2, color2, thickness)

plt.imshow(image)

# %%
#display the modified image
cv2.imshow("Modified Image", image)
cv2.waitKey(0)

# %% [markdown]
# # Drawing a Rectangle on an Image

# %%
from __future__ import print_function
import cv2

# image path 
image_path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
# Read or load image from its path 
image = cv2.imread(image_path) 
# set the start and end coordinates 
# of the top-left and bottom-right corners of the rectangle 

start = (70,100) 
end = (350,220)
# Set the color and thickness of the outline 
color = (0,255,0) 
thickness = 5 
# Draw the rectangle 
cv2.rectangle(image, start, end, color, thickness) 
# Save the modified image with the rectangle drawn to it. 
plt.imshow(image)

# %%
cv2.imwrite("rectangle.jpg", image) 
# Display the modified image 
cv2.imshow("Rectangle", image) 
cv2.waitKey(0)

# %% [markdown]
# # Drawing a Rectangle on a New Canvas and Saving the Image

# %%
from __future__ import print_function
import cv2
import numpy as np

# create a new canvas 
canvas = np.zeros((500, 500, 3), dtype = "uint8")
start = (10,10)
end = (100,100) 
color = (0,0,255) 
thickness = 5 
cv2.rectangle(canvas, start, end, color, thickness) 
plt.imshow(canvas)

# %%
cv2.imwrite("rectangle.jpg", canvas) 
cv2.imshow("Rectangle", canvas) 
cv2.waitKey(0)

# %% [markdown]
# # Drawing a Solid Rectangle on a New Canvas and Saving the Image

# %%
from __future__ import print_function
import cv2
import numpy as np

# create a new canvas 
canvas = np.zeros((500, 500, 3), dtype = "uint8")
start = (10,10)
end = (100,100) 
color = (0,0,255) 
thickness = -1
cv2.rectangle(canvas, start, end, color, thickness) 
plt.imshow(canvas)

# %%
cv2.imwrite("rectangle.jpg", canvas) 
cv2.imshow("Rectangle", canvas) 
cv2.waitKey(0)

# %% [markdown]
# # Drawing a Circle on a Canvas

# %%
from __future__ import print_function
import cv2
import numpy as np
# create a new canvas
canvas = np.zeros((200, 200, 3), dtype = "uint8")
center = (100,100)
radius = 50
color = (0,0,255)
thickness = 5
cv2.circle(canvas, center, radius, color, thickness)
plt.imshow(canvas)

# %%
cv2.imwrite("circle.jpg", canvas) 
cv2.imshow("My Circle", canvas) 
cv2.waitKey(0)

# %% [markdown]
# # Code to Calculate Aspect Ratio and Resize the Image

# %%
from __future__ import print_function
import cv2
import numpy as np
# Load image
imagePath = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
image = cv2.imread(imagePath)
# Get image shape which returns height, width, and channels as a tuple. Calculate the aspect ratio
(h, w) = image.shape[:2]
aspect = w / h
# lets resize the image to  decrease height by half of the original image.
# Remember, pixel values must be integers
height = int(1.5 * h)
width =int(height * aspect)
# New image dimension as a tuple
dimension = (height, width)
resizedImage = cv2.resize(image, dimension, interpolation=cv2.INTER_AREA)
cv2.imshow("Resized Image", resizedImage)
# Resize using x and y factors
resizedWithFactors = cv2.resize(image, None, fx=1.2, fy=1.2, interpolation=cv2.INTER_LANCZOS4)
plt.imshow(resizedWithFactors)

# %%
cv2.imshow("Resized with factors", resizedWithFactors)
cv2.waitKey(0)

# %% [markdown]
# # Image Translation Along the x- and y-Axes

# %%
from __future__ import print_function
import cv2
import numpy as np
#Load image
imagePath = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
image = cv2.imread(imagePath)
#Define translation matrix
translationMatrix = np.float32([[1,0,-100],[0,1,-100]])
#Move the image
movedImage = cv2.warpAffine(image, translationMatrix, (image.shape[1], image.shape[0]))
plt.imshow(movedImage)

# %%
cv2.imshow("Moved image", movedImage)
cv2.waitKey(0)

# %%
image.shape
# Out:
# (225, 360, 3)

# %% [markdown]
# # Rotation

# %%
from __future__ import print_function
import cv2
import numpy as np
# Load image
imagePath = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
image = cv2.imread(imagePath)
(h,w) = image.shape[:2]
#Define translation matrix
center = (h//2, w//2)
angle = 90
scale = 1.0
rotationMatrix = cv2.getRotationMatrix2D(center, angle, scale)
# Rotate the image
rotatedImage = cv2.warpAffine(image, rotationMatrix, (image.shape[1], image.shape[0]))

plt.imshow(rotatedImage)

# %%
cv2.imshow("Rotated image", rotatedImage)
cv2.waitKey(0)

# %%
from __future__ import print_function
import cv2
import numpy as np


# Load image
imagePath = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
image = cv2.imread(imagePath)
# Flip horizontally
flippedHorizontally = cv2.flip(image, 1)

# Flip vertically
flippedVertically = cv2.flip(image, 0)

# Flip horizontally and then vertically
flippedHV = cv2.flip(image, -1)

# %%
plt.imshow(image)

# %%
plt.imshow(flippedHorizontally)

# %%
plt.imshow(flippedVertically)

# %%
plt.imshow(flippedHV)

# %%
cv2.imshow("Flipped Horizontally", flippedHorizontally)
cv2.waitKey(-1)
cv2.imshow("Flipped Vertically", flippedVertically)
cv2.waitKey(-1)
cv2.imshow("Flipped H and V", flippedHV)
cv2.waitKey(-1)

# %% [markdown]
# # Cropping

# %%
from __future__ import print_function
import cv2
import numpy as np
# Load image
imagePath = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"
image = cv2.imread(imagePath)
cv2.imshow("Original Image", image)
cv2.waitKey(0)
# Crop the image to get only the face of the zebra
croppedImage = image[0:150, 0:250]
cv2.imshow("Cropped Image", croppedImage)
cv2.waitKey(0)
# Out:
# -1

# %%
croppedImage = image[100:250, 100:250]
cv2.imshow("Cropped Image", croppedImage)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Image Arithmetic and Bitwise Operations

# %% [markdown]
# # SIMPLE ADDITION and WEIGHTED ADDITION

# %%
from __future__ import print_function
import cv2
import numpy as np

# %%
from __future__ import print_function
import cv2
import numpy as np
image1Path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_3.jpg"
image2Path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/nature_1.jpg"
image1 = cv2.imread(image1Path)
image2 = cv2.imread(image2Path)

# resize the two images to make them of the same dimension. This is a must to add two images
resizedImage1 = cv2.resize(image1,(300,300),interpolation=cv2.INTER_AREA)
resizedImage2 = cv2.resize(image2,(300,300),interpolation=cv2.INTER_AREA)

# This is a simple addition of two images
resultant = cv2.add(resizedImage1, resizedImage2)

# Display these images to see the difference
cv2.imshow("Resized 1", resizedImage1)
cv2.waitKey(0)
cv2.imshow("Resized 2", resizedImage2)

cv2.waitKey(0)
cv2.imshow("Resultant Image", resultant)
cv2.waitKey(0)

# This is weighted addition of the two images
weightedImage = cv2.addWeighted(resizedImage1,0.2, resizedImage2, 0.8, 0)
cv2.imshow("Weighted Image", weightedImage)
cv2.waitKey(0)

imageEnhanced = 255*resizedImage1
cv2.imshow("Enhanced Image", imageEnhanced)
cv2.waitKey(0)

arrayImage = resizedImage1+resizedImage2
cv2.imshow("Array Image", arrayImage)
cv2.waitKey(0)
# Out:
# -1

# %%
weightedImage = cv2.addWeighted(resizedImage1,0.5, resizedImage2, .7, 0)
cv2.imshow("Weighted Image", weightedImage)
cv2.waitKey(0)
# Out:
# -1

# %%
imageEnhanced = 255*resizedImage1
cv2.imshow("Enhanced Image", imageEnhanced)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Subtraction

# %%
import cv2
import numpy as np

image1Path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg"

image2Path = "M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_2.jpg"

image1 = cv2.imread(image1Path)

image2 = cv2.imread(image2Path)

# resize the two images to make them of the same dimensions. This is a must to subtract two images
resizedImage1 = cv2.resize(image1,(int(500*image1.shape[1]/image1. shape[0]), 500),interpolation=cv2.INTER_AREA)
resizedImage2 = cv2.resize(image2,(int(500*image2.shape[1]/image2. shape[0]), 500),interpolation=cv2.INTER_AREA)

cv2.imshow("Cat 1", resizedImage1)

cv2.imshow("Cat 2", resizedImage2)

# Subtract image 1 from 2

cv2.imshow("Diff Cat1 and Cat2",cv2.subtract(resizedImage2, resizedImage1))
cv2.waitKey(0)


# subtract images 2 from 1

subtractedImage = cv2.subtract(resizedImage1, resizedImage2)

cv2.imshow("Cat2 subtracted from Cat1", subtractedImage)
cv2.waitKey(0)

# Numpy Subtraction Cat2 from Cat1

subtractedImage2 = resizedImage2-resizedImage1

cv2.imshow("Numpy Subracts Images", subtractedImage2)

cv2.waitKey(0)

# A constant subtraction

subtractedImage3 = resizedImage1-50

cv2.imshow("Constant Subtracted from the image", subtractedImage3)

cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Bitwise Operations

# %%
# create a circle
circle = cv2.circle(np.zeros((200, 200, 3), dtype = "uint8"), (100,100), 90, (255,255,255), -1)
cv2.imshow("A white circle", circle)
cv2.waitKey(0)
# create a square
square = cv2.rectangle(np.zeros((200,200,3), dtype= "uint8"), (30,30), (170,170),(255,255,255), -1)
cv2.imshow("A white square", square)
cv2.waitKey(0)
#bitwise AND
bitwiseAnd = cv2.bitwise_and(square, circle)
cv2.imshow("AND Operation", bitwiseAnd)
cv2.waitKey(0)
#bitwise OR
bitwiseOr = cv2.bitwise_or(square, circle)
cv2.imshow("OR Operation", bitwiseOr)
cv2.waitKey(0)
#bitwise XOR
bitwiseXor = cv2.bitwise_xor(square, circle)
cv2.imshow("XOR Operation", bitwiseXor)
cv2.waitKey(0)

#bitwise NOT

bitwiseNot = cv2.bitwise_not(square)
cv2.imshow("NOT Operation", bitwiseNot)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Masking Using Bitwise AND Operation

# %%
import cv2
import numpy as np
# Load an image
natureImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
cv2.imshow("Original Nature Image", natureImage)
# Create a rectangular mask
maskImage = cv2.rectangle(np.zeros(natureImage.shape[:2], dtype="uint8"), (80, 80), (360,225), (255, 255, 255), -1)
cv2.imshow("Mask Image", maskImage)

# Using bitwise_and operation perform masking. Notice the mask=maskImage argument
masked = cv2.bitwise_and(natureImage, natureImage, mask=maskImage)
cv2.imshow("Masked image", masked)
cv2.waitKey(0)
# Out:
# -1

# %%
natureImage.shape
# Out:
# (225, 360, 3)

# %% [markdown]
# # Splitting and Merging Channels

# %%
# Load the image
import cv2
natureImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
# Split the image into component colors
(b,g,r) = cv2.split(natureImage)
cv2.imshow("Origianl",natureImage )
# show the blue image
cv2.imshow("Blue Image", b)
# Show the green image
cv2.imshow("Green image", g)
# Show the red image
cv2.imshow("Red image", r)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Split and Merge Functions

# %%
# Load the image
natureImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
# Split the image into component colors
(b,g,r) = cv2.split(natureImage)
# show the blue image


merged = cv2.merge([b,g,r])

# %%
plt.imshow(natureImage)

# %%
plt.imshow(r)

# %%
plt.imshow(g)

# %%
plt.imshow(b)

# %%
cv2.imshow("Blue Image", b)
# Show the green image
cv2.imshow("Green image", g)
# Show the red image
cv2.imshow("Red image", r)
cv2.waitKey(0)
cv2.imshow("Merged Image", merged)
cv2.waitKey(0)

# %%
# Load the image
natureImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/nature_1.jpg")
# Split the image into component colors
(b,g,r) = cv2.split(natureImage)
cv2.imshow("Origianl",natureImage )

merged = cv2.merge([b,r,g])
cv2.imshow("Merged Image", merged)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Mean Filtering or Averaging

# %%
import cv2
import numpy as np
# Load the image
park = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
#Define the kernel
kernel = (3,3)
blurred3x3 = cv2.blur(park,kernel)

blurred5x5 = cv2.blur(park,(5,5))

blurred7x7 = cv2.blur(park, (7,7))

blurred10x10 = cv2.blur(park, (10,10))

# %%
plt.imshow(park)

# %%
plt.imshow(blurred3x3)

# %%
plt.imshow(blurred5x5)

# %%
plt.imshow(blurred7x7)

# %%
plt.imshow(blurred10x10)

# %%
cv2.imshow("Original Park Image", park)


cv2.imshow("3x3 Blurred Image", blurred3x3)

cv2.imshow("5x5 Blurred Image", blurred5x5)

cv2.imshow("7x7 Blurred Image", blurred7x7)

cv2.imshow("10x10 Blurred Image", blurred10x10)
cv2.waitKey(0)

# %% [markdown]
# # Gaussian  Filtering

# %%
import cv2
import numpy as np
# Load the park image
parkImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")

# Gaussian blurring with 3x3 kernel and 0 for standard deviation to calculate from the kernel
GaussianFiltered = cv2.GaussianBlur(parkImage, (7,7), 0)

# %%
plt.imshow(parkImage)

# %%
plt.imshow(GaussianFiltered)

# %%
cv2.imshow("Original Image", parkImage)
cv2.imshow("Gaussian Blurred Image", GaussianFiltered)
cv2.waitKey(0)

# %%
kernel = cv2.getGaussianKernel(10,20)
kernel.shape
# Out:
# (10, 1)

# %% [markdown]
# # Median  Blurring to reduce the salt-and-pepper noise

# %%
import cv2
import numpy as np
# Load a noisy image
saltpepperImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/Salt_Pepper_Noise_3.png")
cv2.imshow("Original noisy image", saltpepperImage)
# Median filtering for noise reduction
blurredImage3 = cv2.medianBlur(saltpepperImage, 3)
cv2.imshow("Blurred image 3", blurredImage3)
# Median filtering for noise reduction
blurredImage5 = cv2.medianBlur(saltpepperImage, 5)
cv2.imshow("Blurred image 5", blurredImage5)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Bilateral Blurring

# %%
import cv2
# Load a noisy image
noisyImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
cv2.imshow("Original image", noisyImage)
# Bilateral Filter with
fileteredImag5 = cv2.bilateralFilter(noisyImage, 5, 150,50)
cv2.imshow("Blurred image 5", fileteredImag5)
# Bilateral blurring with kernal
fileteredImag7 = cv2.bilateralFilter(noisyImage, 7, 160,60)
cv2.imshow("Blurred image 7", fileteredImag7)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Binirazing and Inverse Binarizing Using Threshold Function

# %%
import numpy as np

# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/Scanned_doc_1.jpg")
# convert the image to grayscale
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Grayscale Receipt", image)
# Binarize the image using thresholding
(T, binarizedImage) = cv2.threshold(image, 70, 255, cv2.THRESH_BINARY)
cv2.imshow("Binarized Receipt", binarizedImage)
# Binarization with inverse thresholding
(Ti, inverseBinarizedImage) = cv2.threshold(image, 70, 255, cv2. THRESH_BINARY_INV)
cv2.imshow("Inverse Binarized Receipt", inverseBinarizedImage)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Adaptive Threshold

# %%
import cv2
import numpy as np
# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/Varying_Pixel_Intensity.png")
# convert the image to grayscale
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Grayscale Image", image)

# Binarization using adaptive thresholding and simple mean
binarized = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 7, 3)
cv2.imshow("Binarized Image with Simple Mean", binarized)
# Binarization using adaptive thresholding and Gaussian Mean
binarized = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 3)
cv2.imshow("Binarized Image with Gaussian Mean", binarized)
cv2.waitKey(0)

# %% [markdown]
# # Otsu binarization

# %%
import cv2
import numpy as np

# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/Scanned_doc_1.jpg")
# convert the image to grayscale
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Grayscale Receipt", image)
# Binarize the image using thresholding
(T, binarizedImage) = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print("Threshold value with Otsu binarization", T)
cv2.imshow("Binarized Receipt", binarizedImage)

# Binarization with inverse thresholding
(Ti, inverseBinarizedImage) = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
cv2.imshow("Inverse Binarized Receipt", inverseBinarizedImage)
print("Threshold value with Otsu inverse binazarion", Ti)
cv2.waitKey(0)
# Out:
# Threshold value with Otsu binarization 127.0
# Threshold value with Otsu inverse binazarion 127.0
# -1

# %% [markdown]
# # Sobel and Schar Gradient  Edge Detection

# %%
import cv2
import numpy as np
# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/sudoku_2.jpg")
#cv2.imshow("Original Image", image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.bilateralFilter(image, 5, 50, 50)
#cv2.imshow("Blurred image", image)
# Sobel gradient detection
sobelx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=1)
sobelx = np.uint8(np.absolute(sobelx))
sobely = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=1)
sobely = np.uint8(np.absolute(sobely))

#cv2.imshow("Sobel X", sobelx) 
#cv2.imshow("Sobel Y", sobely)

# Schar gradient detection by passing ksize = -1 to Sobel function
scharx = cv2.Sobel(image,cv2.CV_64F,1,0,ksize=-1)
scharx = np.uint8(np.absolute(scharx))
schary = cv2.Sobel(image,cv2.CV_64F,0,1,ksize=-1)
schary = np.uint8(np.absolute(schary))
#cv2.imshow("Schar X", scharx)
#cv2.imshow("Schar Y", schary)

#cv2.waitKey(0)

# %%
plt.imshow(image)

# %%
plt.imshow(sobelx)

# %%
plt.imshow(sobely)

# %%
plt.imshow(scharx)

# %%
plt.imshow(schary)

# %%
plt.imshow()

# %% [markdown]
# # Edge Detection Using Laplacian Derivatives

# %%
import cv2
import numpy as np
# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/sudoku_1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image = cv2.bilateralFilter(image, 5, 50, 50)

# Laplace function for edge detection
laplace = cv2.Laplacian(image,cv2.CV_64F)
laplace = np.uint8(np.absolute(laplace))

# %%
plt.imshow(image)

# %%
plt.imshow(laplace)

# %%
cv2.imshow("Blurred image", image)
cv2.imshow("Laplacian Edges", laplace)
cv2.waitKey(0)

# %% [markdown]
# # Canny   edge detection

# %%
import cv2
import numpy as np
# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/sudoku_1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#cv2.imshow("Blurred image", image)

# Canny function for edge detection
canny = cv2.Canny(image, 50, 170)
#cv2.imshow("Canny Edges", canny)
#cv2.waitKey(0)

# %%
plt.imshow(image)

# %%
plt.imshow(canny)

# %%
plt.imshow()

# %% [markdown]
# # Contour Detection and Drawing

# %%
import cv2
import numpy as np
# Load an image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/sudoku_1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#cv2.imshow("Blurred image", image)
# Binarize the image
(T,binarized) = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
#cv2.imshow("Binarized image", binarized)
# Canny function for edge detection
canny = cv2.Canny(binarized, 0, 255)
#cv2.imshow("Canny Edges", canny)
(contours, hierarchy) = cv2.findContours(canny,cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

print("Number of contours determined are ", format(len(contours)))
copiedImage = image.copy()
#cv2.drawContours(copiedImage, contours, -1, (0,255,0), 2)
#cv2.imshow("Contours", copiedImage)
#cv2.waitKey(0)
# Out:
# Number of contours determined are  85

# %%
plt.imshow(image)

# %%
plt.imshow(binarized)

# %%
plt.imshow(canny)

# %%
plt.imshow(copiedImage)

# %%
plt.imshow()

# %% [markdown]
# # Histogram of a Grayscale Image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot
# Read an image and convert it to grayscale
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Image", image)
# calculate histogram
hist = cv2.calcHist([image], [0], None, [255], [0,255])
# Plot histogram graph
plot.figure()
plot.title("Grayscale Histogram")
plot.xlabel("Bins")
plot.ylabel("Number of Pixels")
plot.plot(hist)
plot.show()
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Histogram of a Color Image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot
# Read a color image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
cv2.imshow("Original Color Image", image)
#Remember OpenCV stores color in BGR sequence instead of RBG
colors = ("blue", "green", "red")
# calculate histogram
for i, color in enumerate(colors):
    hist = cv2.calcHist([image], [i], None, [12], [0,256] , accumulate=None)
    # Plot histogram graph
    plot.plot(hist, color=color)
plot.title("RGB Color Histogram")
plot.xlabel("Bins")
plot.ylabel("Number of Pixels")
plot.show()
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Histogram of a Color Image with mask

# %%
import cv2
import numpy as np
# Load an image
natureImage = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
cv2.imshow("Original Nature Image", natureImage)
# Create a rectangular mask
maskImage = cv2.rectangle(np.zeros(natureImage.shape[:2], dtype="uint8"), (80, 80), (360,225), (255, 255, 255), -1)
cv2.imshow("Mask Image", maskImage)

# Using bitwise_and operation perform masking. Notice the mask=maskImage argument
masked = cv2.bitwise_and(natureImage, natureImage, mask=maskImage)
cv2.imshow("Masked image", masked)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot
# Read a color image
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")
cv2.imshow("Original Color Image", image)
#Remember OpenCV stores color in BGR sequence instead of RBG
colors = ("blue", "green", "red")
# calculate histogram
for i, color in enumerate(colors):
    hist = cv2.calcHist([image], [i],maskImage, [12], [0,256] , accumulate=None)
    # Plot histogram graph
    plot.plot(hist, color=color)
plot.title("RGB Color Histogram") 
plot.xlabel("Bins")
plot.ylabel("Number of Pixels")
plot.show()
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Histogram Equalization

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plot
# Read an image and convert it into grayscale
image = cv2.imread("M:\Building Computer Vision Applications Using Artificial Neural Networks/jag_1.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Original Image", image)
# calculate histogram of the original image
hist = cv2.calcHist([image], [0], None, [256], [0,255])
# Plot histogram graph
#plot.figure()
plot.title("Grayscale Histogram of Original Image")
plot.xlabel("Bins")
plot.ylabel("Number of Pixels")
plot.plot(hist)
plot.show()

equalizedImage = cv2.equalizeHist(image)
cv2.imshow("Equalized Image", equalizedImage)

# calculate histogram of the original image
histEqualized = cv2.calcHist([equalizedImage], [0], None, [256], [0,255])
# Plot histogram graph
#plot.figure()
plot.title("Grayscale Histogram of Equalized Image")
plot.xlabel("Bins")
plot.ylabel("Number of Pixels")
plot.plot(histEqualized)
plot.show()
cv2.waitKey(0)
# Out:
# -1

# %%
import tensorflow as tf

# %%
from tensorflow import keras
